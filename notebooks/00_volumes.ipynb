# %% [markdown]
# # Criação dos Volumes Databricks

# %%
# %sql
--criação do folder volume
CREATE VOLUME workspace.default.inep_avaliacao_alfabetizacao;

# %%
PASTAS = ["bronze", "silver", "gold"]

for i in PASTAS:
    dbutils.fs.mkdirs(f"/Volumes/workspace/default/inep_avaliacao_alfabetizacao/{i}")

# %%
SUB_PASTAS = ["batch", "streaming"]

for i in SUB_PASTAS:
    dbutils.fs.mkdirs(f"/Volumes/workspace/default/inep_avaliacao_alfabetizacao/bronze/{i}")
